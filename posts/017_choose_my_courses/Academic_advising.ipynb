# %% [raw]
# ---
# title: "Can Chat-gpt-5 Choose My Spring Courses?"
# description: "Exploring how well an LLM's judgemenet comes to choosing my courses vs that of myself & an academic advisor"
# author: "Eleni"
# date: "11/9/2025"
# categories:
#   - LLMs
#   - Academic
# ---

# %% [markdown]
# ![](upenn.png)

# %% [markdown]
# Spring Semester is quickly approaching and like many of you I have been carefully crafting a course cart with Path@penn, penn course review, penn course plan, and the help of an academic advisor. This process can be very time consuming, frustrating, and even anxiety inducing for some individuals. As a result, I wanted to see if an LLM could help with this. Would it be able to navigate the intracacies of UPenn's course requirements? would it be able to correctly identify the differences between our schools (ex: wharton, the college, the school of nursing, etc)? Let's find out.
#
# I decided to be a bit more detailed in this prompt with **Chat-GPT-5**. I outlined all of the courses that I have already taken and clearly stated my academic level etc. Instead of explaining, Let me just show you! My prompts will be in **red** and Chat's will be in **blue**

# %% [markdown]
# <div style="background-color:#ffe6e6; padding:14px 16px; border-radius:10px; border:1px solid #ff4d4d;">
#   <p style="margin:8px 0;">
#     I am a third year student at the University of Pennsylvania. I am majoring in Economics and Minoring In data science &amp; analytics in the college of arts and sciences. I am currently in my fall semester and I need to choose courses for my spring semester.
#   </p>
#   <p style="margin:8px 0;">
#     Here are all of the courses I have already taken:
#   </p>
#   <ul style="margin:8px 0 12px 20px;">
#     <li>Math 1400</li>
#     <li>Math 1410</li>
#     <li>COMM 4190</li>
#     <li>STAT 4300</li>
#     <li>STAT 4310</li>
#     <li>ECON 0100</li>
#     <li>ECON 0200</li>
#     <li>ECON 2100</li>
#     <li>ECON 2200</li>
#     <li>SPAN 0100</li>
#     <li>SPAN 0200</li>
#     <li>SPAN 0300</li>
#     <li>SPAN 0400</li>
#     <li>EALC 1242</li>
#     <li>GSWS 2700</li>
#     <li>MATH 1300</li>
#     <li>WRIT 0250</li>
#     <li>COML 1701</li>
#     <li>CIMS 1004</li>
#     <li>PHYS 1100</li>
#     <li>CIMS 1800</li>
#     <li>STAT 4750</li>
#     <li>PSYC 0001</li>
#   </ul>
#   <p style="margin:8px 0;">
#     I need you to create a mock schedule of 4–6 classes for spring. You can find the available courses through UPenn's various websites and you can find the requirements for graduation there as well.
#   </p>
# </div>

# %% [markdown]
# <div style="background-color:#e6f2ff; padding:16px 18px; border-radius:10px; border:1px solid #4d79ff;">
#
# awesome—here are two *ready-to-register* mock schedules (5 courses each) that move you toward (a) the ECON BA and (b) finishing the College Data Science & Analytics minor (DASA). I’m aligning these with the official degree rules and the spring-typical offerings noted in the Penn catalog.
#
# # Option A: Quant & econ-core sprint
#
# * **ECON 2310 Econometric Methods & Models** — completes the *Econometrics* requirement for the Econ BA (you’ve already satisfied the “Statistics” requirement via STAT 4300 + 4310). ([University of Pennsylvania Catalog][1])
# * **ECON 4410 Public Finance (4000-level ECON elective)** — counts toward the 4 required 4000-level ECON electives. Catalog lists as Fall or Spring. ([University of Pennsylvania Catalog][2])
# * **ECON 4510 International Trade (4000-level ECON elective)** — another 4000-level elective; listed Fall or Spring. ([University of Pennsylvania Catalog][2])
# * **STAT 4710 Modern Data Mining** — counts for the DASA *Applied Data Science* bucket; offered Fall or Spring. Prereq satisfied by STAT 4310. ([University of Pennsylvania Catalog][3])
# * **CIS 4190 Applied Machine Learning** — appears on the DASA “Applied Data Science (Python)” list; good bridge between econ and DS. ([SAS at Penn][4])
#
# **Why this works:**
#
# * Econ BA: You already have ECON 0100, 0200, 2100, 2200, and Math 1400/1410. Adding **ECON 2310** completes the econometrics core; **ECON 4410** and **ECON 4510** push you 2/4 into the required 4000-level ECON electives. ([University of Pennsylvania Catalog][1])
# * DASA minor: Your past **STAT 4300, STAT 4310, PHYS 1100, STAT 4750** already cover “Math & Stats,” “Intro DS & Programming,” and one *Elective*. **STAT 4710** (Applied DS) + **CIS 4190** (Applied DS Python list) move you closer to the 6-course structure. ([SAS at Penn][4])
#
# # Option B: Policy/impact + methods
#
# * **ECON 2310 Econometric Methods & Models** — Econ BA econometrics (as above). ([University of Pennsylvania Catalog][1])
# * **ECON 4340 Empirical Economics of Climate Change (4000-level)** — methods-heavy, policy angle; listed Fall or Spring. ([University of Pennsylvania Catalog][2])
# * **ECON 4480 Economics of Education (4000-level)** — listed Fall or Spring; builds causal inference intuition. ([University of Pennsylvania Catalog][2])
# * **STAT 4420 Introduction to Bayesian Data Analysis** — Spring offering; great for causal/forecast-y econ work; also on the DASA *Applied* list. ([University of Pennsylvania Catalog][3])
# * **COMM 3130 Computational Text Analysis (DASA elective)** — on the DASA elective list; applies NLP to social-science questions. ([SAS at Penn][4])
#
# **Why this works:**
#
# * Econ BA: **ECON 2310** + two 4000-level ECONs progress you cleanly toward the 4 upper-level electives. ([University of Pennsylvania Catalog][1])
# * DASA minor: **STAT 4420** covers the *Applied Data Science* slot; **COMM 3130** adds another approved DS elective. (Reminder: DASA requires 6 courses total with specific core/elective mix and overlap limits.) ([SAS at Penn][4])
#
# ---
#
# ## Quick audit of where you stand (per the official rules)
#
# * **Econ BA structure (2025–26 catalog):** 2 c.u. math; intro micro/macro; intermediate micro/macro; stats (via ECON 2300 *or* STAT 4300+4310); **ECON 2310 econometrics**; **four 4000-level ECON electives**. You’ve completed everything except **ECON 2310** and the 4000-level electives. ([University of Pennsylvania Catalog][1])
# * **DASA minor (College):** 6 courses → 3 “core” (Intro DS & Programming; Math & Statistics; Applied DS) + 3 *Electives* from the approved list; page also lists many approved courses you’ve taken or could take (PHYS 1100, STAT 4300/4310, STAT 4750, STAT 4710, CIS 4190, etc.). ([SAS at Penn][4])
#
# ---
#
# ## Nice alternates if sections/time conflicts pop up
#
# * **ECON 4330 Econometric Machine Learning Methods & Models (4000-level)** — advanced econ/ML; typically after 2310. ([University of Pennsylvania Catalog][2])
# * **ECON 4405 Economic Program Evaluation (4000-level)** — causal inference focus; recommended after 2310. ([University of Pennsylvania Catalog][2])
# * **STAT 4700 Data Analytics & Statistical Computing** — R + workflows (counts for DASA Applied list). ([University of Pennsylvania Catalog][3])
#
# ---
#
# ### How to lock these in
#
# * Verify specific **Spring 2026** sections and times on **Path@Penn** / Course Search; the catalog shows which are *typically* offered in Spring and the official degree rules. (Econ BA PDF and DASA minor page above are the authoritative requirement sources.) ([University of Pennsylvania Catalog][1])
#
# If you want, tell me which option vibes more (or mix & match), plus any constraints (no Friday classes, max 4 courses, specific profs), and I’ll shape it into a day-by-day schedule with backup sections.
#
# [1]: https://catalog.upenn.edu/undergraduate/programs/economics-ba/economics-ba.pdf "Economics, BA"
# [2]: https://catalog.upenn.edu/courses/econ/ "Economics (ECON) < University of Pennsylvania"
# [3]: https://catalog.upenn.edu/courses/stat/ "Statistics and Data Science (STAT) < University of Pennsylvania"
# [4]: https://web.sas.upenn.edu/data-science/data-science-minor/ "Data Science and Analytics Minor | Data Science"
#
# </div>

# %% [markdown]
# I am **shocked** that Chat identified that I took the STAT 4300+4310 route instead of the ECON 2300 route. I have had many colleagues who had **academic advisors** not catch that before.
#
# Furthermore, this doesn't stray too far from the courses I actually chose for next semester. I hope to take ECON 2310 (identified in all options from the LLM), ECON 4410 (option A in the LLM), another ECON elective, and a general elective.
#
# Here are some of its pitfalls:
# - It did not identify or offer suggestions for gen ed course requirements I am missing
# - It did not offer other general electives (however, this could be fixed if I added my other interests in the prompt)

# %% [markdown]
# ## Thank you for reading
