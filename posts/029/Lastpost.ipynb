# %% [raw]
# ---
# title: "Last Blog for Class, Not the Last Post"
# description: "Wrapping up my final class blog and reflecting on what’s next for my website"
# author: "Eleni"
# date: "12/18/2025"
# categories:
#   - Reflection
#   - Academic
#   - COMM 4190
#   - HTML
# ---

# %% [markdown]
# ## Final Words
#
# This has been quite the adventure! Thank you for sticking around - I hope that it was as fun for you as it has been for me! While this is the last post required for my Communications class, I wanted to reassure you that it is not my final post here. The direction and focus of my website may develop and change as we go but I plan to continue to explore what large language models limits are and what they have to offer us. In addition, I won't be changing the aesthetics of my earlier posts (yes, some are a bit ugly aesthetically) but I see the progression in readability and style as representative of how much I've grown this semester. I've learned so much about language, coding, websites, and collaborative work than I ever have before in such a short time.
#
# Thank you for a wonderful semester,
# Eleni

# %% [markdown]
# <iframe width="560" height="315" src="https://www.youtube.com/embed/ORQMCkYU1WA?si=5h-7Tfjoj3HQnwSR" title="YouTube video player" frameborder="0" allow="accelerometer; autoplay; clipboard-write; encrypted-media; gyroscope; picture-in-picture; web-share" referrerpolicy="strict-origin-when-cross-origin" allowfullscreen></iframe>
