# %% [raw]
# ---
# title: "What do LLM's see?"
# description: "Exploring how LLM's interperet images"
# author: "Eleni"
# date: "11/28/2025"
# categories:
#   - LLMs
#   - Creativity
#   - Experiment
# ---

# %% [markdown]
# ## Introduction:
# Hey readers! Today we will be exploring how LLMs interpret images. I will be working with **Chat-GPT-5.1 thinking**. For this experiment, I will be feeding Chat an image and asking it to describe the image in as much detail as it can. I will then be using that description and feeding it to a fresh chat with chat-gpt and asking it to create an image that looks like the description. We'll be looking at a few different types of images and they will get increasingly more complex. I won't be sharing the parts where I ask it to create the image because I'm just going to write "create the following image: *Insert chats description*" and thats going to be pretty boring to read 4 times.

# %% [markdown]
# ## Test 1

# %% [markdown]
# ![](realpuppies.png)

# %% [markdown]
# > <div style="background-color:#fff9c4; padding:10px; border-radius:8px;">
# > <strong>USER:</strong><br>
# > Describe this image in as much detail as you can.<br>
# > </div>
# >
# > <div style="background-color:#dcfce7; padding:10px; border-radius:8px;">
# > <strong>ASSISTANT:</strong><br>
# > In the image, there are two fluffy golden retriever puppies sitting side-by-side on a grassy field.<br><br>
# > The puppy on the left has slightly darker golden fur, especially around its ears and back.
# > Its mouth is open wide with a long pink tongue hanging out, giving it a very happy, relaxed expression.
# > Its ears droop down on either side of its head, and its eyes look soft and gentle, facing slightly toward the camera.<br><br>
# > The puppy on the right is a bit lighter in color, more creamy-gold than the left one.
# > Its mouth is also open as if mid-pant or mid-bark, with a pink tongue visible and tiny teeth showing.
# > Its head is turned slightly toward the left puppy, and its chest fur looks extra fluffy.<br><br>
# > The two puppies are sitting very close together, their shoulders touching so they look like best friends or siblings.
# > The background is a soft blur of green, suggesting a large grassy park, and there are scattered orange and yellow flower petals
# > around their paws that add warm pops of color. The overall feeling is bright, playful, and very cute.
# > </div>

# %% [markdown]
# ![](aipuppies.png)

# %% [markdown]
# Overall, I'm pretty surprised with this result. It's definitely more natural and representative of the original image than I thought it would be. Even with a fairly short description, chat was able to capture its likeliness

# %% [markdown]
# ## Test 2

# %% [markdown]
# ![](reallily.png)

# %% [markdown]
# > <div style="background-color:#dbeafe; padding:10px; border-radius:8px;">
# > <strong>USER:</strong><br>
# > Describe this image in as much detail as you possibly can.<br>
# > </div>
# >
# > <div style="background-color:#dcfce7; padding:10px; border-radius:8px;">
# > <strong>ASSISTANT:</strong><br>
# > The image shows a close-up of a delicate flowering plant, strongly resembling lily of the valley, but with an almost otherworldly, bluish coloration.<br><br>
# > <strong>Flowers and structure</strong><br>
# > – Several arching, slender green stems curve from the upper right toward the center and lower left of the image.<br>
# > – Hanging from these stems are many small, bell-shaped flowers.<br>
# > – Each flower is about the size of a fingertip, with smooth, curved petals that flare slightly at the bottom in 5–6 rounded lobes.<br>
# > – The flowers are a cool, pale blue that shifts toward silvery white where the light hits them, giving them a soft, luminous look.<br>
# > – The bells hang in clusters along the stems, each on its own thin, pale green stalk. Some stalks are straight, others slightly bent, which makes the bells look like they’re gently drooping or swaying.<br><br>
# > <strong>Water droplets and beads</strong><br>
# > – The most striking feature is the presence of water.<br>
# > – Individual droplets cling to the surfaces of the bell petals, especially near the edges and lower curves; some look like tiny glass marbles stuck to the flowers.<br>
# > – Between and beneath the flowers, there are long vertical strings of spherical droplets or beads. They look almost like strands of crystal or raindrops frozen in midair.<br>
# > – These beads catch highlights: each sphere has a bright highlight where the light reflects, and darker shading on the opposite side, so they look very three-dimensional.<br>
# > – In some places, smaller droplets seem to be mid-fall, suspended in front of or behind the flowers, adding to the sense of motion and depth.<br><br>
# > <strong>Lighting and color</strong><br>
# > – The lighting is low and cool, suggesting either shade, early morning, or evening.<br>
# > – The flowers themselves appear softly illuminated, as if lit by a diffused, bluish light source. This makes the blue bells glow gently against a darker background.<br>
# > – The background is blurred (shallow depth of field), with deep greens and near-blacks that emphasize the flowers in the foreground.<br>
# > – Subtle reflections from the water droplets create tiny points of light, almost like stars or fairy lights scattered among the bells.<br><br>
# > <strong>Leaves and background elements</strong><br>
# > – To the right, behind the hanging stems, there are larger, smooth green leaves. One major leaf curves upward, catching a bit of light along its edge.<br>
# > – The leaves are slightly out of focus but still recognizable by their broad shape and glossy surface.<br>
# > – In the dark background, there are hints of more foliage—soft shapes and streaks of green and blue, completely blurred, which keeps attention on the main cluster of flowers.<br><br>
# > <strong>Overall impression and composition</strong><br>
# > – The composition is vertical: the main stem arcs from the top right toward the center, and the strings of droplets and flowers cascade downward.<br>
# > – The focus is sharp on the central bells and water beads, gradually softening outward, which draws the eye into the middle of the image.<br>
# > – The combination of the cool blue tones, crystal-clear droplets, and dark, soft background gives the image a serene, almost magical atmosphere—like a nighttime or rainy-forest close-up where the flowers and beads look almost jewel-like or ethereal.
# > </div>

# %% [markdown]
# ![](ailily.png)

# %% [markdown]
# This next image I felt was a little bit more complex, and chat output a far more detailed description. It didn't pick up on the colors like I thought it would.. I can't really describe it, but this just *feels* like its lacking something

# %% [markdown]
# ## Test 3
# ![](realfamily.png)

# %% [markdown]
# > <div style="background-color:#dbeafe; padding:10px; border-radius:8px;">
# > <strong>USER:</strong><br>
# > Please describe this image in as much detail as you possibly can.<br>
# > </div>
# >
# > <div style="background-color:#dcfce7; padding:10px; border-radius:8px;">
# > <strong>ASSISTANT:</strong><br>
# > In the image, seven people are sitting closely together on a fluffy white surface, posed for what looks like a cozy holiday photo. The group fills almost the entire width of the frame, aligned in a straight line and leaning slightly toward one another so there are no gaps between them. The overall color palette is warm and soft: lots of whites, creams, tans, and browns, with pops of red from the decorations and little details in their clothing.<br><br>
# > <strong>Background and setting</strong><br>
# > – Behind them is an elaborate, festive backdrop that feels very Christmas-themed.<br>
# > – At the very top, a thick garland of evergreen branches stretches across the upper edge of the image, dusted with what looks like artificial snow.<br>
# > – Tucked into the greenery are round ornaments in metallic gold and matte red, pinecones, and other baubles, with a large red bow hanging from the center of the garland.<br>
# > – Below the garland is an arched structure that looks like a whimsical, oversized cookie or candy arch, rimmed by a thick candy-cane stripe of red and white diagonal bands curving over the group.<br>
# > – A soft row of small lights traces the inside of the arch, giving the scene a gentle glow.<br>
# > – Within the arch, the backdrop is a pale, creamy beige color with decorative elements: small star ornaments in shades of gold, bronze, and red, plus a few red star outlines.<br>
# > – Near the center top is a white ornamental flourish—like carved scrollwork—adding to the cozy, staged feel.<br>
# > – Just behind their shoulders is what looks like a padded, upholstered headboard or large cushion in a soft cream color, with vertical panels that resemble a curved headboard.<br>
# > – They are sitting on a very fluffy white blanket or faux-fur throw that covers the entire bottom of the image, making the scene look extra soft and warm.<br><br>
# > <strong>Matching outfits</strong><br>
# > – Everyone except the middle child is wearing matching holiday pajamas.<br>
# > – The pajama tops are raglan-style long-sleeve shirts with light tan sleeves and collar and a white body.<br>
# > – On the front of each shirt is the same playful design with the words “COOKIE BAKING CREW” in large, bold black and red lettering, with rows of red dots, candy-cane accents, and a small gingerbread figure incorporated into the design.<br>
# > – Their pajama pants match as well: white or off-white fabric covered in a repeating pattern of gingerbread people, candy canes, and other cookie shapes in browns and reds.<br>
# > – The smallest child in front is wearing bright red and black striped socks, visible where his legs are folded on the fluffy blanket.<br>
# > – The middle child, who breaks the pattern slightly, is wearing a cozy, textured light-beige sweater with a diamond or cable-knit pattern, which still fits the neutral color palette.<br><br>
# > <strong>People from left to right</strong><br>
# > – <em>Far left:</em> An older boy or teen with light brown hair that’s relatively long on top and swoops across his forehead, slightly tousled. He’s smiling broadly with his teeth showing and eyes gently squinted. He wears the full “COOKIE BAKING CREW” pajama set and appears to be sitting with his legs bent or crossed on the blanket.<br>
# > – <em>Second from left:</em> An adult woman with medium-length, wavy blonde hair parted slightly off-center. She has a big, warm smile that shows braces, and her eyes are almost closed from the size of her smile. She’s also in the matching pajamas, with one hand resting near the small boy in front of her in an affectionate, protective way.<br>
# > – <em>Third from left (front small child):</em> A young boy sitting slightly forward in front of the woman. He has straight, light brown hair cut in a simple style that falls over his forehead. His eyes are partly closed, and he has a soft, relaxed smile, as if caught mid-blink. He wears the matching pajama set and red-and-black striped socks, sitting cross-legged or with folded legs, hands resting loosely in his lap.<br>
# > – <em>Center child:</em> Directly in the middle is a child slightly older than the small boy. They have straight, light brown hair parted in the center and falling just past their shoulders, framing their face symmetrically. They wear the light beige textured sweater with a diamond knit pattern. Their smile is gentle and closed-lip, and they sit upright, looking calmly at the camera.<br>
# > – <em>Third from right:</em> A teen girl or young person with light blonde hair that reaches around the shoulders, cut in slightly layered fashion with long bangs that sweep across the forehead and partially cover one eye. She wears the matching pajama set, leans slightly forward with hands clasped together in her lap, and has a small, friendly smile that feels a bit shy.<br>
# > – <em>Second from right (adult man):</em> An adult man with very short, light hair—blonde or light brown—neatly trimmed close to his head. He has a broad, open smile showing his teeth and bright eyes. He is also in the matching pajama outfit and sits slightly back behind the others, leaning forward so his face fits within the frame.<br>
# > – <em>Far right:</em> Another older boy or teen with light brown hair, a bit longer on top and swept to one side, with shorter sides. He’s smiling widely with teeth visible and slightly squinted eyes. He wears the same pajama set, his torso angled slightly toward the rest of the group, helping to complete the gentle inward curve of the group’s arrangement.<br><br>
# > <strong>Overall feel and composition</strong><br>
# > – The seven people are seated very close together, shoulders touching or nearly touching, with the smallest child positioned slightly forward, creating a layered look.<br>
# > – The fluffy white blanket, the coordinated “COOKIE BAKING CREW” pajamas, and the candy-cane arch backdrop all contribute to a playful, staged holiday-card aesthetic, as if taken in a studio designed for Christmas or winter portraits.<br>
# > – The lighting is soft and even, with no harsh shadows; everyone’s faces are clearly visible and gently illuminated, and the warm, slightly muted tones add to the cozy feeling.<br>
# > – Overall, the image conveys a happy, relaxed, and festive mood, highlighting togetherness and holiday cheer centered around a cookie-baking theme.<br>
# > </div>

# %% [markdown]
# ![](aifamily.png)

# %% [markdown]
# So, I've just realized that my promots for this the last two image generations and the first one are different. For the last two I added "Possibly" by mistake. I am going to continue the rest with that prompt to keep consistency. I also felt like this image would be a challenge for the LLM, but I didn't expect it to change anyones gender (in the center in the white sweater is a boy in the original photo with a girl alongside their right). Perhaps chat has a very traditional understanding of gender and the long hair confused it? I'm really not sure.
#
#
# For the final test we are looking at an internet oddity. This image is described in online forums such as reddit and 4chan as containing a lot of objects with viewers being unable to discern what the contents of the image actually are. I want to see if chat can discern any of the objects, and if it cant, how good is it at recreating the image at least.

# %% [markdown]
# ## Test 4

# %% [markdown]
# ![](internetmystery.png)

# %% [markdown]
# > <div style="background-color:#dbeafe; padding:10px; border-radius:8px;">
# > <strong>USER:</strong><br>
# > Describe this image in as much detail as you possibly can.<br>
# > </div>
# >
# > <div style="background-color:#dcfce7; padding:10px; border-radius:8px;">
# > <strong>ASSISTANT:</strong><br>
# > The image looks like a surreal, heavily distorted indoor scene, almost like several photographs have been blended or melted together into a single, dreamlike picture.<br><br>
# > <strong>Overall composition</strong><br>
# > – The image is roughly square, with a thin white border framing the scene.<br>
# > – The setting appears to be indoors, with beige-tan walls and a light surface—possibly a table or bed—occupying much of the lower part of the image.<br>
# > – Everything has a smeared, painterly quality: objects blur into one another, edges are soft, and many shapes appear only half-formed, as if the image were an abstract collage rather than a clear photograph.<br><br>
# > <strong>Background and environment</strong><br>
# > – The back wall is a smooth beige color, most visible in the upper right and upper center areas, with soft, diffuse shadows but no distinct decorations.<br>
# > – Along the right side, there seems to be a pale, diagonal element that looks like a stair rail or a low ledge running from the lower right toward the upper center.<br>
# > – Behind some of the central clutter, near the right, there are brownish rectangular shapes that resemble boxes or framed objects leaning against the wall, though their outlines are fuzzy and partially obscured.<br><br>
# > <strong>Lower left: white displays and jewelry-like objects</strong><br>
# > – The lower left quadrant is one of the more structured areas, dominated by two white rectangular display stands set at slight angles.<br>
# > – Each stand looks like a jewelry or earring rack: a white frame around a grid of horizontal lines with many small dark spots, suggesting rows of tiny items such as earrings, hooks, or beads.<br>
# > – These stands sit in front of darker masses that might be bags or folded fabric, but the forms are smudged together.<br>
# > – On the light surface beneath them are scattered pale shapes, including what looks like a ring or loop of translucent pieces—evoking a necklace or garland of beads—and several rounded, glossy blobs in cream, pale yellow, and soft pink, like scattered ornaments or reflections.<br>
# > – The surface itself is smooth and light beige or off-white, with gentle shadows that make it feel like a tablecloth or bedspread draped across the bottom of the scene.<br><br>
# > <strong>Upper left and center: vertical structures and blurred figures</strong><br>
# > – In the upper left, there is a tall vertical structure that resembles a chair, mannequin, or display stand.<br>
# > – It has a narrow, upright back predominantly dark blue, mixed with browns and tans, and seems to sit on or behind a jumble of colorful shapes near its base.<br>
# > – Around the middle of the image, overlapping this area, are forms that feel like partially dissolved people or mannequins: hints of shoulders, torsos, and clothing appear, but none are clearly defined.<br>
# > – The colors here are rich and varied—deep blues, reds, and warm browns—interspersed with bright highlights, adding to the sense of a cluttered, busy interior space.<br><br>
# > <strong>Upper right: overlapping animal-like faces</strong><br>
# > – The upper right and mid-right sections are dominated by shapes that look like they once were faces but have been layered and warped together.<br>
# > – Near the center-right, you can make out something like the side profile of a small animal—perhaps a deer, dog, or rodent—with a rounded snout, a distinct dark eye, and a soft tan-brown head shape.<br>
# > – Above and slightly behind this, a lighter, cream-colored face seems superimposed: you can see a suggestion of another eye and nose, but it blends into the surrounding textures.<br>
# > – These face-like forms melt into red, white, and beige areas around them, giving the impression of multiple overlapping figures fused into one surreal cluster.<br><br>
# > <strong>Bottom right: large dark creature-like form</strong><br>
# > – The most striking single element appears in the bottom right quadrant: a large dark, rounded mass that resembles the head of a strange creature.<br>
# > – The top and left sides of this form are covered in deep brown or nearly black texture, evoking thick fur or hair.<br>
# > – Near the upper middle of the dark shape is a prominent eye-like circle: a grayish ring with a darker center, strongly suggesting a staring eye emerging from the fur.<br>
# > – Below that, toward the lower middle, there are bright warm patches of orange, peach, and red that look like a beak or mouth—almost as if a bird’s beak is protruding from this furry mass.<br>
# > – Around and partly attached to this dark form are vivid red, crinkled shapes, reminiscent of tissue paper, gift wrap, or bright fabric bunched up around the “creature.”<br>
# > – The boundary between this form and the pale surface at the bottom right is soft and blurred, making it hard to tell where the creature-like shape ends and the background begins.<br><br>
# > <strong>Color, texture, and style</strong><br>
# > – The color palette is warm and busy: many browns, creams, beiges, and whites, punctuated by bright reds, oranges, and occasional blues.<br>
# > – The textures are smeared and painterly, as if the image were made with oil paint or produced by an algorithm that blends multiple photos into one.<br>
# > – There are almost no crisp edges; jewelry displays morph into cloth, faces dissolve into walls, and decorations become abstract patches of color.<br><br>
# > <strong>Overall impression</strong><br>
# > – The scene feels like a warped snapshot of a cluttered room or market stall—perhaps filled with jewelry displays, fabric, boxes, and figures—but all twisted together into one surreal image.<br>
# > – There is no single clear subject; instead, the eye keeps catching on half-recognizable forms: a rack of jewelry, a chair, a snout, an eye, fur, bright red wrapping, then losing them again in the abstraction.<br>
# > – Overall, the picture gives off an uncanny, dreamlike mood, as though you are looking at a memory or collage where real objects and creatures have been melted into a strange, visually dense hallucination.<br>
# > </div>

# %% [markdown]
# ![](ai.png)

# %% [markdown]
# Maybe I'm overdo for a new pair of glasses but this is VERY far from the original image. That being said, I did not expect chat to do very well on this image. What did you think of this experiment? are there things you think I could have done better / differently? Reach out! let's chat. My contact information for github and linkedin can be found on the homepage of this website.
#
# ## Thank You For Reading
