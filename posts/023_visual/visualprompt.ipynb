# %% [raw]
# ---
# title: "What do LLM's see?"
# description: "Exploring how LLM's interperet images"
# author: "Eleni"
# date: "11/28/2025"
# categories:
#   - LLMs
#   - Creativity
#   - Experiment
# ---
