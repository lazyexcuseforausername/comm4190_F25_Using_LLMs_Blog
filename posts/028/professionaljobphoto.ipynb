# %% [raw]
# ---
# title: "Google Gemini 3 Flash: Building a Professional Job Photo"
# description: "Google Gemini 3 Flash to polish a LinkedIn-ready headshot plan and practice interview answers/questions"
# author: "Eleni"
# date: "12/12/2025"
# categories:
#   - Career
#   - Professional
#   - Academic
#   - Creative
# ---

# %% [markdown]
# ## Introduction
#
# Okay so for this blog I wanted to do something a little different (and honestly more useful for real life): a fun experiment with **Google Gemini 3 Flash** where I see how much it can help with the “professional job search” things that I always end up procrastinating (specifically, getting a solid headshot)
#
# The purpose of this post is basically to test if Gemini can act like a lowkey career helper. Like, can it help me get a professional headshot for my Linkedin profile without shelling out the money and time to get a photographer?
#
#
# ## Professional Photo
# Gemini actually had an option I could click on to explore professional photos, and when I clicked on it, it auto sent the following message
#
#
# <div style="
#   background: radial-gradient(circle at 12% 18%, #ffe4f1 0%, rgba(255,228,241,0) 45%),
#               radial-gradient(circle at 88% 30%, #e0f2fe 0%, rgba(224,242,254,0) 42%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 48%),
#               linear-gradient(135deg, #fff7ed 0%, #ffffff 55%, #fdf2f8 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="
#     display:flex; align-items:center; gap:10px; margin-bottom:10px;
#   ">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #fb7185, #60a5fa);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       USER
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.75);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#     line-height: 1.45;
#     font-size: 14.5px;
#   ">
#     First ask me for a selfie.<br><br>
#     Transform my selfie into a fresh but professional image suitable for a social media profile.
#     The lighting should be natural, flattering, and multidimensional. My head is slightly tilted
#     so it doesn't look stiff and it should look like I'm in a modern, bright office with a blurred background.
#   </div>
# </div>
#
#
#
# <div style="
#   background: radial-gradient(circle at 14% 18%, #e0f2fe 0%, rgba(224,242,254,0) 48%),
#               radial-gradient(circle at 88% 28%, #fae8ff 0%, rgba(250,232,255,0) 45%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 50%),
#               linear-gradient(135deg, #f8fafc 0%, #ffffff 55%, #eff6ff 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #a78bfa, #22d3ee);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       GEMINI
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.78);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#     line-height: 1.45;
#     font-size: 14.5px;
#   ">
#     <img src="gem.png" alt="Gemini" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
# <div style="
#   background: radial-gradient(circle at 12% 18%, #ffe4f1 0%, rgba(255,228,241,0) 45%),
#               radial-gradient(circle at 88% 30%, #e0f2fe 0%, rgba(224,242,254,0) 42%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 48%),
#               linear-gradient(135deg, #fff7ed 0%, #ffffff 55%, #fdf2f8 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #fb7185, #60a5fa);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       USER
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.75);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="mirror.png" alt="User image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
#
# <div style="
#   background: radial-gradient(circle at 14% 18%, #e0f2fe 0%, rgba(224,242,254,0) 48%),
#               radial-gradient(circle at 88% 28%, #fae8ff 0%, rgba(250,232,255,0) 45%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 50%),
#               linear-gradient(135deg, #f8fafc 0%, #ffffff 55%, #eff6ff 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #a78bfa, #22d3ee);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       GEMINI
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.78);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="care.png" alt="Gemini image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
# <div style="
#   background: radial-gradient(circle at 12% 18%, #ffe4f1 0%, rgba(255,228,241,0) 45%),
#               radial-gradient(circle at 88% 30%, #e0f2fe 0%, rgba(224,242,254,0) 42%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 48%),
#               linear-gradient(135deg, #fff7ed 0%, #ffffff 55%, #fdf2f8 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #fb7185, #60a5fa);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       USER
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.75);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="black.png" alt="User image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
# <div style="
#   background: radial-gradient(circle at 14% 18%, #e0f2fe 0%, rgba(224,242,254,0) 48%),
#               radial-gradient(circle at 88% 28%, #fae8ff 0%, rgba(250,232,255,0) 45%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 50%),
#               linear-gradient(135deg, #f8fafc 0%, #ffffff 55%, #eff6ff 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #a78bfa, #22d3ee);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       GEMINI
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.78);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="glass.png" alt="Gemini image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
#
# <div style="
#   background: radial-gradient(circle at 12% 18%, #ffe4f1 0%, rgba(255,228,241,0) 45%),
#               radial-gradient(circle at 88% 30%, #e0f2fe 0%, rgba(224,242,254,0) 42%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 48%),
#               linear-gradient(135deg, #fff7ed 0%, #ffffff 55%, #fdf2f8 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #fb7185, #60a5fa);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       USER
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.75);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="butter.png" alt="User image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
#
# <div style="
#   background: radial-gradient(circle at 14% 18%, #e0f2fe 0%, rgba(224,242,254,0) 48%),
#               radial-gradient(circle at 88% 28%, #fae8ff 0%, rgba(250,232,255,0) 45%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 50%),
#               linear-gradient(135deg, #f8fafc 0%, #ffffff 55%, #eff6ff 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #a78bfa, #22d3ee);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       GEMINI
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.78);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="office.png" alt="Gemini image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
# <div style="
#   background: radial-gradient(circle at 12% 18%, #ffe4f1 0%, rgba(255,228,241,0) 45%),
#               radial-gradient(circle at 88% 30%, #e0f2fe 0%, rgba(224,242,254,0) 42%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 48%),
#               linear-gradient(135deg, #fff7ed 0%, #ffffff 55%, #fdf2f8 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #fb7185, #60a5fa);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       USER
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.75);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="puro.png" alt="User image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
# <div style="
#   background: radial-gradient(circle at 14% 18%, #e0f2fe 0%, rgba(224,242,254,0) 48%),
#               radial-gradient(circle at 88% 28%, #fae8ff 0%, rgba(250,232,255,0) 45%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 50%),
#               linear-gradient(135deg, #f8fafc 0%, #ffffff 55%, #eff6ff 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #a78bfa, #22d3ee);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       GEMINI
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.78);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="gold.png" alt="Gemini image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
# <div style="
#   background: radial-gradient(circle at 12% 18%, #ffe4f1 0%, rgba(255,228,241,0) 45%),
#               radial-gradient(circle at 88% 30%, #e0f2fe 0%, rgba(224,242,254,0) 42%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 48%),
#               linear-gradient(135deg, #fff7ed 0%, #ffffff 55%, #fdf2f8 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #fb7185, #60a5fa);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       USER
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.75);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#     line-height: 1.45;
#     font-size: 14.5px;
#   ">
#     I don't like that image, create a new one
#   </div>
# </div>
#
#
# <div style="
#   background: radial-gradient(circle at 14% 18%, #e0f2fe 0%, rgba(224,242,254,0) 48%),
#               radial-gradient(circle at 88% 28%, #fae8ff 0%, rgba(250,232,255,0) 45%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 50%),
#               linear-gradient(135deg, #f8fafc 0%, #ffffff 55%, #eff6ff 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #a78bfa, #22d3ee);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       GEMINI
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.78);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="green.png" alt="Gemini image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>
#
#
#
# <div style="
#   background: radial-gradient(circle at 12% 18%, #ffe4f1 0%, rgba(255,228,241,0) 45%),
#               radial-gradient(circle at 88% 30%, #e0f2fe 0%, rgba(224,242,254,0) 42%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 48%),
#               linear-gradient(135deg, #fff7ed 0%, #ffffff 55%, #fdf2f8 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #fb7185, #60a5fa);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       USER
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.75);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#     line-height: 1.45;
#     font-size: 14.5px;
#   ">
#     I want it to look more professional
#   </div>
# </div>
#
#
# <div style="
#   background: radial-gradient(circle at 14% 18%, #e0f2fe 0%, rgba(224,242,254,0) 48%),
#               radial-gradient(circle at 88% 28%, #fae8ff 0%, rgba(250,232,255,0) 45%),
#               radial-gradient(circle at 30% 92%, #dcfce7 0%, rgba(220,252,231,0) 50%),
#               linear-gradient(135deg, #f8fafc 0%, #ffffff 55%, #eff6ff 100%);
#   border: 1px solid rgba(0,0,0,0.08);
#   border-radius: 16px;
#   padding: 14px 16px;
#   box-shadow: 0 10px 24px rgba(0,0,0,0.08);
#   font-family: ui-sans-serif, system-ui, -apple-system, Segoe UI, Roboto, Helvetica, Arial;
# ">
#   <div style="display:flex; align-items:center; gap:10px; margin-bottom:10px;">
#     <div style="
#       width:34px; height:34px; border-radius:10px;
#       background: linear-gradient(135deg, #a78bfa, #22d3ee);
#       box-shadow: 0 8px 16px rgba(0,0,0,0.10);
#     "></div>
#     <div style="font-weight:800; letter-spacing:0.08em; font-size:13px;">
#       GEMINI
#     </div>
#   </div>
#
#   <div style="
#     background: rgba(255,255,255,0.78);
#     border: 1px solid rgba(0,0,0,0.06);
#     border-radius: 14px;
#     padding: 12px 12px;
#   ">
#     <img src="response.png" alt="Gemini response image" style="
#       width: 100%;
#       height: auto;
#       border-radius: 12px;
#       display: block;
#       border: 1px solid rgba(0,0,0,0.06);
#       box-shadow: 0 8px 18px rgba(0,0,0,0.10);
#     ">
#   </div>
# </div>

# %% [markdown]
# ## Reflection:
#
# Should I have been more direct about what I wanted from the LLM? Absolutely. However, the LLM was also supposed to follow the direction in the beginning to ask me for a photo of myself and it didnt so I guess we're both in the wrong 🤷
#
# Some of the photos actually aren't bad (for example, I quite like the recreation of the one where I'm wearing a blue sweater) However, the last three at the end don't really look enough like me. I find it interesting that Gemini smooths out the skin so much but focused on smaller details that I didn't think it would notice (such as my blueberry necklace).
#
# ## Conclusion
# Yeah I think the answer is pretty clear...get the photographer!
#
# # Thanks for reading!
